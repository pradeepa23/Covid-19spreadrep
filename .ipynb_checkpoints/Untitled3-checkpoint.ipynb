# %%
import requests
import pprint

# %%
res=requests.get('https://api.rootnet.in/covid19-in/stats/latest')
dir(res)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
res.json()
# Out:
# {'success': True,
#  'data': {'summary': {'total': 10581837,
#    'confirmedCasesIndian': 10581789,
#    'confirmedCasesForeign': 48,
#    'discharged': 10228753,
#    'deaths': 152556,
#    'confirmedButLocationUnidentified': 0},
#   'unofficial-summary': [{'source': 'covid19india.org',
#     'total': 7945975,
#     'recovered': 7198877,
#     'deaths': 119538,
#     'active': 626192}],
#   'regional': [{'loc': 'Andaman and Nicobar Islands',
#     'confirmedCasesIndian': 4988,
#     'confirmedCasesForeign': 0,
#     'discharged': 4897,
#     'deaths': 62,
#     'totalConfirmed': 4988},
#    {'loc': 'Andhra Pradesh',
#     'confirmedCasesIndian': 886066,
#     'confirmedCasesForeign': 0,
#     'discharged': 877212,
#     'deaths': 7141,
#     'totalConfirmed': 886066},
#    {'loc': 'Arunachal Pradesh',
#     'confirmedCasesIndian': 16812,
#     'confirmedCasesForeign': 0,
#     'discharged': 16699,
#     'deaths': 56,
#     'totalConfirmed': 16812},
#    {'loc': 'Assam',
# ...

# %%
data=r

# %%
pprint.pprint(data)
# Out:
# {'data': {'regional': [{'confirmedCasesForeign': 0,
#                         'confirmedCasesIndian': 4988,
#                         'deaths': 62,
#                         'discharged': 4897,
#                         'loc': 'Andaman and Nicobar Islands',
#                         'totalConfirmed': 4988},
#                        {'confirmedCasesForeign': 0,
#                         'confirmedCasesIndian': 886066,
#                         'deaths': 7141,
#                         'discharged': 877212,
#                         'loc': 'Andhra Pradesh',
#                         'totalConfirmed': 886066},
#                        {'confirmedCasesForeign': 0,
#                         'confirmedCasesIndian': 16812,
#                         'deaths': 56,
#                         'discharged': 16699,
#                         'loc': 'Arunachal Pradesh',
#                         'totalConfirmed': 16812},
#                        {'confirmedCasesForeign': 0,
# ...

# %%
with open('data.json','w') as fp:
    fp.write(str(data))

# %%
import pandas as pd

# %%
df=pd.read_html('https://www.mygov.in/covid-19/')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-cfbe58497be1> in <module>
# ----> 1 df=pd.read_html('https://www.mygov.in/covid-19/')
#
# ~\Anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1098         na_values=na_values,
#    1099         keep_default_na=keep_default_na,
# -> 1100         displayed_only=displayed_only,
#    1101     )
#
# ~\Anaconda3\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     913             break
#     914     else:
# --> 915         raise retained
#     916
#     917     ret = []
#
# ~\Anaconda3\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined
